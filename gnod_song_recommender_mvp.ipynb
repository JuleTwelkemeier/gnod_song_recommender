# %% [markdown]
# # GNOD Song Recommender - MVP

# %% [markdown]
# ![mind_mao_song_recommender.jpeg](attachment:mind_mao_song_recommender.jpeg)

# %%
from song_recommender_code import pick_song

# %%
#pick_song()
